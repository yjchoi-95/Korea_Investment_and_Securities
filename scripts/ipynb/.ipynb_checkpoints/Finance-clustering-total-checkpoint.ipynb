# %% [markdown]
# ## Import

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import silhouette_score, silhouette_samples

import pandas as pd
import numpy as np
import re, os

# %% [markdown]
# * load data

# %%
data_path = "C:\\Users\\PC\\OneDrive\\문서\\GitHub\\Korea_Investment_and_Securities\\datasets\\"

# %%
out_data_path = "C:\\Users\\PC\\OneDrive\\문서\\datasets\\"

# %%
sector_df = pd.read_csv(data_path + "sector_df.csv")
stock_01 = pd.read_csv(data_path + "stock_df_01.csv")
tot_df = pd.read_csv(data_path + "tot_df.csv", encoding = "cp949")
tot_df.Symbol = [x.split(".")[0] if "." in x else x for x in tot_df.Symbol]

# %%
tot_df.head()
# Out:
#   Symbol                                           Name       Industry  \
# 0    TSM  Taiwan Semiconductor Manufacturing Co Ltd ADR   반도체 및 반도체 장비
# 1      V                               Visa Inc Class A  소프트웨어 및 IT서비스
# 2    JPM                            JPMorgan Chase & Co             은행
# 3    UNH                         UnitedHealth Group Inc  헬스케어 업체 및 서비스
# 4    JNJ                              Johnson & Johnson             제약
#
#    IndustryCode
# 0      571010.0
# 1      572010.0
# 2      551010.0
# 3      561020.0
# 4      562010.0

# %% [markdown]
# * make group df

# %%
'''
sector_df = pd.merge(sector_df, stock_01, on = "etf_names", how = "inner")

group_df = sector_df.groupby(["sector", "stock_names"])['etf_names'].count().reset_index()

for idx, sec in enumerate(group_df.sector.unique()):
    temp_df = group_df.loc[group_df.sector == secs]
    temp_df = temp_df.sort_values("etf_names", ascending = False)
    
    if idx == 0 :
        group_df_f = temp_df
    else :
        group_df_f = group_df_f.append(temp_df)

group_df_f.index = [x for x in range(group_df_f.shape[0])]
group_df['stock_names'] = [re.sub(",","",x) for x in group_df.stock_names]
group_df_f.to_csv(data_path + "group_df.csv", index = False)
'''
# Out:
# '\nsector_df = pd.merge(sector_df, stock_01, on = "etf_names", how = "inner")\n\ngroup_df = sector_df.groupby(["sector", "stock_names"])[\'etf_names\'].count().reset_index()\n\nfor idx, sec in enumerate(group_df.sector.unique()):\n    temp_df = group_df.loc[group_df.sector == secs]\n    temp_df = temp_df.sort_values("etf_names", ascending = False)\n    \n    if idx == 0 :\n        group_df_f = temp_df\n    else :\n        group_df_f = group_df_f.append(temp_df)\n\ngroup_df_f.index = [x for x in range(group_df_f.shape[0])]\ngroup_df[\'stock_names\'] = [re.sub(",","",x) for x in group_df.stock_names]\ngroup_df_f.to_csv(data_path + "group_df.csv", index = False)\n'

# %%
group_df = pd.read_csv(data_path + "group_df.csv")

# %%
group_df.head()
# Out:
#                 sector                   stock_names  etf_names
# 0  Aerospace & Defense                     AAR CORP.          3
# 1  Aerospace & Defense             HEICO Corporation          3
# 2  Aerospace & Defense  Northrop Grumman Corporation          3
# 3  Aerospace & Defense             Moog Inc. Class A          3
# 4  Aerospace & Defense          Mercury Systems Inc.          3

# %%
group_df.shape
# Out:
# (138767, 3)

# %% [markdown]
# * clustering per sector

# %%
def print_symbol(name, etf_name, tot_df):
    if name == 'U.S. Dollar':
        return '-'
    # 탐색 key value 선정
    temp_key_value = name.split(" ")
    key_value = temp_key_value[0]

    # TDM 구축
    total_name = []
    total_name.extend(etf_name)
    total_name.extend(list(tot_df.Name))

    tokenizer = CountVectorizer()
    tdm=tokenizer.fit_transform(total_name)

    first_select = [idx for idx, x in enumerate(total_name) if (x == name) or ((x.startswith(key_value)) and idx > len(etf_name))]

    if len(first_select) == 2:
        output_idx = first_select[1] - len(etf_name)
    elif len(first_select) == 1:
        return "-"
    else:
        sims = cosine_similarity(tdm[first_select[0]], tdm[first_select[1:]])
        output_idx = first_select[1:][np.argmax(sims)] - len(etf_name)

#    print("name: ", name,"\nresult:", tot_df.Name[output_idx])
    output = tot_df.iloc[output_idx].Symbol
    return output.split(".")[0]

# %%
etf_name = ["Berkshire Hathaway Inc. Class B",
"JPMorgan Chase & Co.", 
"Citigroup Inc.",
"Goldman Sachs Group, Inc."]

# %%
symbol = print_symbol(etf_name[3], etf_name, tot_df); symbol
# Out:
# 'GS'

# %% [markdown]
# * clustering

# %%
from tqdm import tqdm

# %%
symbol_dict = {}

# %%
'''
# sector 별로 루프
#for sec in tqdm(group_df.sector.unique()):
for idx, sec in enumerate(group_df.sector.unique()):
    print(idx / group_df.sector.unique().shape[0])
    temp_df = group_df.loc[group_df.sector == sec,:]
    
    # symbol check, 오래걸림
    sec_symbols = []
    for stock in tqdm(temp_df.stock_names):
        symbol = print_symbol(stock, temp_df.stock_names, tot_df)
        if symbol == "-":
            continue
        
        sec_symbols.append(symbol)
    
    symbol_dict[sec] = sec_symbols    
'''

# %%
import pickle

# %%
'''
with open(out_data_path + 'symbol_dict.pickle', 'wb') as f:
    pickle.dump(symbol_dict, f, pickle.HIGHEST_PROTOCOL)
'''
# Out:
# "\nwith open(out_data_path + 'symbol_dict.pickle', 'wb') as f:\n    pickle.dump(symbol_dict, f, pickle.HIGHEST_PROTOCOL)\n"

# %%
with open(out_data_path + "symbol_dict.pickle", "rb") as f:
    symbol_dict = pickle.load(f)

# %% [markdown]
# * imputation

# %%
from sklearn.impute import KNNImputer

# %%
stock_02 = pd.read_csv(out_data_path + "stock_df_02.csv")

'''
select_col = [x for x in stock_02.columns if "_" not in x]
select_col.extend([x for x in stock_02.columns if ("_x" in x) and (".") not in x])
stock_02 = stock_02.loc[:, select_col]
col_names = [x for x in stock_02.columns if "_" not in x]
col_names.extend([x.split("_")[0] for x in stock_02.columns if "_" in x])
stock_02.columns = col_names
stock_02.to_csv(out_data_path + "stock_df_02.csv", index = False)
'''
# Out:
# '\nselect_col = [x for x in stock_02.columns if "_" not in x]\nselect_col.extend([x for x in stock_02.columns if ("_x" in x) and (".") not in x])\nstock_02 = stock_02.loc[:, select_col]\ncol_names = [x for x in stock_02.columns if "_" not in x]\ncol_names.extend([x.split("_")[0] for x in stock_02.columns if "_" in x])\nstock_02.columns = col_names\nstock_02.to_csv(out_data_path + "stock_df_02.csv", index = False)\n'

# %%
half_nan  = np.where(stock_02.isnull().sum(axis = 0) <= stock_02.shape[0] * 0.45)[0]

# %%
stock_02 = stock_02.iloc[:, half_nan]

# %%
imputer = KNNImputer(n_neighbors=5)

# %%
imputed_x = imputer.fit_transform(np.array(stock_02.iloc[:, 1:]))

# %%
imputed_x.shape

# %% [markdown]
# * scaling

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
#scaler = StandardScaler()
scaler = MinMaxScaler()

# %%
scaled_x= scaler.fit_transform(imputed_x)

# %%
scaled_x.shape

# %%
stock_02.loc[:, "TSM":] = scaled_x
# stock_02.iloc[:, 1:] = scaled_x

# %%
stock_02.head()

# %%
stock_02.shape

# %%
#stock_02.to_csv(out_data_path + "scaled_stocks.csv", index = False)
#stock_02.to_csv(out_data_path + "mm_scaled_stocks.csv", index = False)

# %%
group_df.head()
# Out:
#                 sector                   stock_names  etf_names
# 0  Aerospace & Defense                     AAR CORP.          3
# 1  Aerospace & Defense             HEICO Corporation          3
# 2  Aerospace & Defense  Northrop Grumman Corporation          3
# 3  Aerospace & Defense             Moog Inc. Class A          3
# 4  Aerospace & Defense          Mercury Systems Inc.          3

# %% [markdown]
# * clustering

# %%
from tslearn.clustering import TimeSeriesKMeans

import matplotlib.pyplot as plt

# %%
stock_02 = pd.read_csv(out_data_path + "scaled_stocks.csv")

# %%
temp_stock = stock_02.loc[stock_02.Date >= "2017-01-01","TSM":]

# %%
cluster_input = np.expand_dims(np.array(temp_stock.T), 2)

# %%
cluster_input.shape
# Out:
# (4520, 1310, 1)

# %% [markdown]
# * select best number of cluster

# %%
cluster_score_dict = {}

# %%
max_iter = 45

# %%
for n_ in range(3, max_iter):
    model = TimeSeriesKMeans(n_clusters=n_, random_state=0, n_jobs = -1,verbose = True)
    y_pred = model.fit_predict(cluster_input)
    score = silhouette_score(cluster_input.reshape(cluster_input.shape[0], cluster_input.shape[1]), y_pred)
    cluster_score_dict[str(n_)] = score

# %%
cluster_score_dict
# Out:
# {'3': 0.2527044643174836,
#  '4': 0.20529960744571507,
#  '5': 0.1942578189468913,
#  '6': 0.17299181017075804,
#  '7': 0.16673416293460572,
#  '8': 0.143199622639132,
#  '9': 0.13311002150559664,
#  '10': 0.1334635026799685,
#  '11': 0.13252551866841253,
#  '12': 0.13520569219103246,
#  '13': 0.13040428020860284,
#  '14': 0.12504086963766492,
#  '15': 0.12230335858320826,
#  '16': 0.12205107671828216,
#  '17': 0.1196970332481138,
#  '18': 0.1183732800725371,
#  '19': 0.11877262653516174,
#  '20': 0.11405140898518892,
#  '21': 0.10138212608085305,
#  '22': 0.09952155451051246,
#  '23': 0.09658086340589865,
#  '24': 0.09542278288463835,
#  '25': 0.09471886302878402,
#  '26': 0.09923345944909912,
#  '27': 0.09239554129161714,
#  '28': 0.09181490750797773,
#  '29': 0.09287834730887139,
#  '30': 0.09160105858808942,
#  '31': 0.09159500180335005,
#  '32': 0.09132820938180146,
#  '33': 0.09253022944215675,
#  '34': 0.09115595712200669,
#  '35': 0.08993982518561167,
#  '36': 0.08789690879877701,
#  '37': 0.08695561437400594,
#  '38': 0.08560382603568378,
#  '39': 0.08404170445243375,
#  '40': 0.0838783937920062,
#  '41': 0.08267647377815567,
#  '42': 0.08436641361888365,
#  '43': 0.08371299894024521,
#  '44': 0.0831718288689975}

# %%
'''with open(data_path + "cluster_dict_tot.pickle", "wb") as f:
    pickle.dump(select_n_dict, f, pickle.HIGHEST_PROTOCOL)'''

# %%
with open(data_path + "cluster_dict_tot.pickle", "rb") as f:
    select_n_dict = pickle.load(f)

# %% [markdown]
# * clustering

# %%
dir_path = os.getcwd() + os.path.sep + "results_tot" 
if not os.path.isdir(dir_path):
    os.mkdir(dir_path)

# %%
save_path = dir_path + os.path.sep

# %%
np.min(np.where(cluster_input < -8, -5, cluster_input))
# Out:
# -7.923233701749375

# %%
np.max(np.where(cluster_input > 8, 5, cluster_input))
# Out:
# 7.958699086764192

# %%
cluster_input = np.where(cluster_input < -8, -7.923233701749375, cluster_input)
cluster_input = np.where(cluster_input > 8, 7.958699086764192, cluster_input)

# %%
temp_tot = tot_df.loc[tot_df.Symbol.isin(temp_stock.columns), :]

# %%
names = [tot_df.loc[tot_df.Symbol == x, "Name"].values[0] for x in temp_stock.columns]

# %%
for n_ in range(3, max_iter):
    model = TimeSeriesKMeans(n_clusters=n_, random_state=0, n_jobs = -1,verbose = True)
    y_pred = model.fit_predict(cluster_input)

    if n_ == 3:
        result_df = pd.DataFrame({"Symbol": temp_stock.columns, "Name": names, "Cluster_{}".format(n_): y_pred})
    else:
        temp_df = pd.DataFrame({"Symbol": temp_stock.columns, "Name": names, "Cluster_{}".format(n_): y_pred})
        result_df = pd.merge(result_df, temp_df)
    
    if not os.path.isdir(save_path + str(n_)):
        os.mkdir(save_path + str(n_))

    total_loop = int(np.ceil(n_/4))

    start_idx = 0
    end_idx = np.min([4, n_])

    for i in range(total_loop):
        # plotting
        plt.figure(figsize = (64,64))
        fig, ax = plt.subplots(2, 2, figsize=(16,8))
        fig.tight_layout()

        row_idx = 0
        col_idx = 0

        for yi in range(start_idx, end_idx):
            for xx in cluster_input[y_pred == yi]:
                ax[row_idx, col_idx].plot(xx.ravel(), "k-", alpha=.2)
            ax[row_idx, col_idx].plot(model.cluster_centers_[yi].ravel(), "r-")
            ax[row_idx, col_idx].set_title("Euclidean Cluster {n} of {m}".format(n = yi+1, m = n_))
            ax[row_idx, col_idx].set_ylim(np.min(cluster_input)-0.1, np.max(cluster_input) + 0.1)

            if col_idx != 1:
                col_idx += 1
            else :
                row_idx += 1
                col_idx = 0
                
        plt.savefig(save_path + str(n_) + os.path.sep + 'Euclidean_{}.png'.format(i), dpi=300)
        start_idx += 4
        end_idx = np.min([end_idx + 4, n_])

# %%
# result_df.to_csv(save_path + "result_df_tot.csv", index = False)

# %%
y_pred.shape
# Out:
# (4520,)

# %%
temp_idx = np.where(y_pred == 18)[0]

# %%
temp_names = np.array(names)[temp_idx]

# %%
data
# Out:
# array([66, 50, 42, 48, 85, 98])

# %%
group_df.head()
# Out:
#                 sector                   stock_names  etf_names
# 0  Aerospace & Defense                     AAR CORP.          3
# 1  Aerospace & Defense             HEICO Corporation          3
# 2  Aerospace & Defense  Northrop Grumman Corporation          3
# 3  Aerospace & Defense             Moog Inc. Class A          3
# 4  Aerospace & Defense          Mercury Systems Inc.          3

# %%
temp_names[2]
# Out:
# 'Thor Industries Inc'

# %%
group_name = ['FedEx Corporation', 'Polaris Inc.', 'hor Industries Inc.']

# %%
[x for x in group_df.stock_names if x.startswith("Thor")]
# Out:
# ['Thor Industries Inc. 4.0% 15-OCT-2029',
#  'Thornburg Mortgage Securities Trust 2007-2 A2A 2.04857% 25-JUN-2037',
#  'Thornburg Mortgage Securities Trust 2006-5 A1 2.672787% 25-AUG-2036',
#  'Thor Industries Inc.',
#  'Thor Industries Inc.',
#  'Thor Industries Inc.',
#  'Thorne HealthTech Inc.',
#  'Thor Industries Inc. 4.0% 15-OCT-2029',
#  'Thornton Colo Ctfs Partn 5.0% 01-DEC-2022',
#  'Thornburg Mortgage Securities Trust 2005-1 A3 2.127845% 25-APR-2045',
#  'Thornton Colo Ctfs Partn 4.0% 01-DEC-2022',
#  'Thornton Colo Dev Auth Tax Increment 5.0% 01-DEC-2022',
#  'Thor Industries Inc.',
#  'Thoresen Thai Agencies Public Co. Ltd.',
#  'Thor Industries Inc.',
#  'Thorne HealthTech Inc.']

# %%
group_df.loc[group_df.stock_names == 'Thor Industries Inc.']
# Out:
#                         sector           stock_names  etf_names
# 54676                 Consumer  Thor Industries Inc.          1
# 55576   Consumer Discretionary  Thor Industries Inc.          1
# 59882                   Growth  Thor Industries Inc.          8
# 123194         Theme Investing  Thor Industries Inc.          1
# 132024                   Value  Thor Industries Inc.         20

# %%
from collections import Counter
Counter(tot_df.loc[tot_df.Name.isin(temp_names),:].Industry)
# Out:
# Counter({'화물 및 물류 서비스': 2,
#          '레저 상품': 2,
#          '보험': 1,
#          '메탈&마이닝': 4,
#          '전문품 상점': 2,
#          '커뮤니케이션 및 네트워킹': 1,
#          '다양한 소매업': 2,
#          '주택건설': 2,
#          '다양한 금융서비스': 5,
#          '운송업': 1,
#          '전자 장비 및 부품': 1,
#          '음료': 1,
#          '건설장비 및 대형차, 기차, 배': 5,
#          '자동차 및 자동차 부품': 1,
#          '반도체 및 반도체 장비': 5,
#          '건설 및 엔지니어링': 2,
#          '생명과학 및 메디컬 리서치': 3,
#          '소프트웨어 및 IT서비스': 4,
#          '식품 및 담배': 1,
#          '섬유 및 의류': 1,
#          '헬스케어 장비 및 용품': 1,
#          '제약': 1,
#          '은행': 1,
#          '컴퓨터, 전화 및 가전제품': 1,
#          '통신 서비스': 1,
#          '사무기기': 1,
#          '미디어 및 출판': 1})

# %%
data = np.random.randint(20, 100, 6)
plt.pie(data, labels = ['A', 'B', 'C', 'D', 'E', 'F'])
circle = plt.Circle( (0,0), 0.7, color='white')
p = plt.gcf()
p.gca().add_artist(circle)
plt.show()

# %% [markdown]
# * plotting shihouette

# %%
from yellowbrick.cluster import SilhouetteVisualizer

# %%
visualizer_2 = SilhouetteVisualizer(model, colors='yellowbrick')
#생성된 visualizer에 데이터 입력
fitting = visualizer_2.fit(cluster_input.reshape(cluster_input.shape[0], cluster_input.shape[1]))
# Out:
# C:\Users\PC\anaconda3\lib\site-packages\tslearn\utils\utils.py:89: UserWarning: 2-Dimensional data passed. Assuming these are 7 1-dimensional timeseries
#   '{} 1-dimensional timeseries'.format(X.shape[0]))
# C:\Users\PC\anaconda3\lib\site-packages\tslearn\utils\utils.py:89: UserWarning: 2-Dimensional data passed. Assuming these are 4520 1-dimensional timeseries
#   '{} 1-dimensional timeseries'.format(X.shape[0]))

# %%
for n_ in range(3, max_iter):
    model = TimeSeriesKMeans(n_clusters=n_, random_state=0, n_jobs = -1,verbose = True)
    y_pred = model.fit_predict(cluster_input)
    score = silhouette_score(cluster_input.reshape(cluster_input.shape[0], cluster_input.shape[1]), y_pred)
    cluster_score_dict[str(n_)] = score

# %%
sil_avg = silhouette_score(cluster_input.reshape(cluster_input.shape[0], cluster_input.shape[1]), y_pred)
sil_values = silhouette_samples(cluster_input.reshape(cluster_input.shape[0], cluster_input.shape[1]), y_pred)

# %%
y_lower = 10
axs[ind].set_title('Number of Cluster : '+ str(n_cluster)+'\n' \
                  'Silhouette Score :' + str(round(sil_avg,3)) )
axs[ind].set_xlabel("The silhouette coefficient values")
axs[ind].set_ylabel("Cluster label")
axs[ind].set_xlim([-0.1, 1])
axs[ind].set_ylim([0, len(X_features) + (n_cluster + 1) * 10])
axs[ind].set_yticks([])  # Clear the yaxis labels / ticks
axs[ind].set_xticks([0, 0.2, 0.4, 0.6, 0.8, 1])

# %%
# 클러스터링 갯수별로 fill_betweenx( )형태의 막대 그래프 표현. 
for i in range(n_cluster):
    ith_cluster_sil_values = sil_values[cluster_labels==i]
    ith_cluster_sil_values.sort()

    size_cluster_i = ith_cluster_sil_values.shape[0]
    y_upper = y_lower + size_cluster_i

    color = cm.nipy_spectral(float(i) / n_cluster)
    axs[ind].fill_betweenx(np.arange(y_lower, y_upper), 0, ith_cluster_sil_values, \
                        facecolor=color, edgecolor=color, alpha=0.7)
    axs[ind].text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
    y_lower = y_upper + 10

axs[ind].axvline(x=sil_avg, color="red", linestyle="--")

# %% [markdown]
# * 개별 종목

# %%
n_ = 5

# %%
model = TimeSeriesKMeans(n_clusters=n_, random_state=0, n_jobs = -1,verbose = True)
y_pred = model.fit_predict(cluster_input)

#if n_ == 2:
if n_ == 3:
    result_df = pd.DataFrame({"Symbol":temp_stock.loc[:, temp_stock.columns.isin(symbols)].columns,
                              "cluster_{}".format(n_) : y_pred})
else:
    temp_df = pd.DataFrame({"Symbol":temp_stock.loc[:, temp_stock.columns.isin(symbols)].columns,
                              "cluster_{}".format(n_) : y_pred})
    result_df = pd.merge(result_df, temp_df)


# plotting
plt.figure(figsize = (64,64))
fig, ax = plt.subplots(int(np.ceil(n_/2)), 2, figsize=(16,8))
fig.tight_layout()

row_idx = 0
col_idx = 0

for yi in range(n_):
    for xx in cluster_input[y_pred == yi]:
        ax[row_idx, col_idx].plot(xx.ravel(), "k-", alpha=.2)
    ax[row_idx, col_idx].plot(model.cluster_centers_[yi].ravel(), "r-")
    ax[row_idx, col_idx].set_title("{symbol} Euclidean Cluster {n} of {m}".format(symbol = sym_name, n = yi+1, m = n_))
    ax[row_idx, col_idx].set_ylim(np.min(cluster_input)-0.1, np.max(cluster_input) + 0.1)

    if col_idx != 1:
        col_idx += 1
    else :
        row_idx += 1
        col_idx = 0
# Out:
# 765.373 --> 533.468 --> 524.811 --> 519.283 --> 515.454 --> 513.758 --> 512.655 --> 511.108 --> 508.564 --> 504.842 --> 501.992 --> 500.089 --> 499.264 --> 498.620 --> 498.095 --> 497.748 --> 497.563 --> 497.403 --> 497.298 --> 497.221 --> 497.142 --> 497.108 --> 497.093 --> 497.080 --> 497.051 --> 497.038 --> 497.028 --> 497.022 --> 497.019 --> 497.016 --> 497.006 --> 496.990 --> 496.972 --> 496.963 --> 496.959 --> 496.958 --> 496.958 -->

# %%
describe_df = stock_02.describe()

# %%
over_idx = np.where(stock_02.iloc[:,1:].max(axis =0) > 10)[0]
over_idx = [1+x for x in over_idx]

# %%
stock_02.iloc[:, over_idx].plot(figsize = (12,8)).legend(loc="upper right")
